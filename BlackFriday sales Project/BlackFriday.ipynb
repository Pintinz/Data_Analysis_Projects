# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pip install git
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement git (from versions: none)
# ERROR: No matching distribution found for git
#
# [notice] A new release of pip is available: 23.1.2 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv("BlackFriday.csv") #Dataset imported

# %%
df.head() #displaying first 5 rows
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %% [markdown]
# ### Checking Number of Nils in each column

# %%
df.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
df.dropna(axis = 1, inplace= True) #Removing nil values in the column axis

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Purchase                    537577 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 41.0+ MB

# %%
df.nunique() #checking number of unique values in the dataset column
# Out:
# User_ID                        5891
# Product_ID                     3623
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               18
# Purchase                      17959
# dtype: int64

# %%
df.describe() #analysing the statistical value of the dataset
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#             Purchase
# count  537577.000000
# mean     9333.859853
# std      4981.022133
# min       185.000000
# 25%      5866.000000
# 50%      8062.000000
# 75%     12073.000000
# max     23961.000000

# %%
df.head(25)
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0   1000001  P00069042      F   0-17          10             A
# 1   1000001  P00248942      F   0-17          10             A
# 2   1000001  P00087842      F   0-17          10             A
# 3   1000001  P00085442      F   0-17          10             A
# 4   1000002  P00285442      M    55+          16             C
# 5   1000003  P00193542      M  26-35          15             A
# 6   1000004  P00184942      M  46-50           7             B
# 7   1000004  P00346142      M  46-50           7             B
# 8   1000004   P0097242      M  46-50           7             B
# 9   1000005  P00274942      M  26-35          20             A
# 10  1000005  P00251242      M  26-35          20             A
# 11  1000005  P00014542      M  26-35          20             A
# 12  1000005  P00031342      M  26-35          20             A
# 13  1000005  P00145042      M  26-35          20             A
# ...

# %%
df.groupby(["Product_ID", "Gender"]).value_counts() #Grouping dataset based on their product id and gender
# Out:
# Product_ID  Gender  User_ID  Age    Occupation  City_Category  Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# P00000142   F       1000001  0-17   10          A              2                           0               3                   13650       1
#                     1000006  51-55  9           A              1                           0               3                   10620       1
#                     1000018  18-25  3           B              3                           0               3                   10854       1
#                     1000028  26-35  1           C              2                           1               3                   8059        1
#                     1000034  18-25  0           A              0                           0               3                   13521       1
#                                                                                                                                           ..
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Purchase'],
#       dtype='object')

# %%
df["User_ID"].nunique() #getting the number of unique values in USER ID
# Out:
# 5891

# %%
user_id = df["User_ID"].unique() #

customers = df["User_ID"]

# %%
df["User_ID"].value_counts().max()
# Out:
# np.int64(1025)

# %%
df.value_counts() #Returning counts of unique rows in the dataframe
# Out:
# User_ID  Product_ID  Gender  Age    Occupation  City_Category  Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 1006040  P00349442   M       26-35  6           B              2                           0               6                   16389       1
# 1000001  P00000142   F       0-17   10          A              2                           0               3                   13650       1
#          P00004842   F       0-17   10          A              2                           0               3                   13645       1
#          P00025442   F       0-17   10          A              2                           0               1                   15416       1
#          P00051442   F       0-17   10          A              2                           0               8                   9938        1
#                                                                                                                                           ..
# ...

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby("Age").size() #Getting the size of all age groups
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
df_26_35 = df[(df["Age"] == "26-35") & (df["Gender"] == "M")] #subset of age range for male genders

# %%
df_26_35.head()
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 5   1000003  P00193542      M  26-35          15             A
# 9   1000005  P00274942      M  26-35          20             A
# 10  1000005  P00251242      M  26-35          20             A
# 11  1000005  P00014542      M  26-35          20             A
# 12  1000005  P00031342      M  26-35          20             A
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 5                           3               0                   1     15227
# 9                           1               1                   8      7871
# 10                          1               1                   5      5254
# 11                          1               1                   8      3957
# 12                          1               1                   8      6073

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Purchase'],
#       dtype='object')

# %%
df_m = df_26_35[['User_ID', 'Product_ID', 'Occupation', 'City_Category',  'Marital_Status', 'Product_Category_1', 'Purchase']].groupby(["Product_ID", 'Occupation', 'City_Category',  'Marital_Status', 'Product_Category_1']).agg({"Purchase":sum})
# Out:
# C:\Users\Osas\AppData\Local\Temp\ipykernel_4072\410218716.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df_m = df_26_35[['User_ID', 'Product_ID', 'Occupation', 'City_Category',  'Marital_Status', 'Product_Category_1', 'Purchase']].groupby(["Product_ID", 'Occupation', 'City_Category',  'Marital_Status', 'Product_Category_1']).agg({"Purchase":sum})

# %%
df["Occupation"].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %%
# df_m.sort_values("Purchase", ascending = False, inplace = True)

# %%
df_m.head(30)
# Out:
#                                                                        Purchase
# Product_ID Occupation City_Category Marital_Status Product_Category_1
# P00000142  0          A             0              3                      62640
#                                     1              3                      48236
#                       B             0              3                      91514
#                                     1              3                      92287
#                       C             0              3                      72711
#                                     1              3                      83394
#            1          A             0              3                      24442
#                                     1              3                      24054
#                       B             0              3                      40280
#                                     1              3                      56519
# ...

# %%
df_26_35
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 5       1000003  P00193542      M  26-35          15             A
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...         ...        ...    ...    ...         ...           ...
# 537540  1004732  P00124642      M  26-35          14             B
# 537541  1004732  P00051442      M  26-35          14             B
# 537542  1004732  P00085242      M  26-35          14             B
# 537543  1004732  P00117242      M  26-35          14             B
# 537544  1004732  P00093342      M  26-35          14             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 5                               3               0                   1
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Purchase'],
#       dtype='object')

# %%
m = df["User_ID"].unique()

# %%
m
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529])

# %%
df_ = df[['User_ID', 'Purchase', "Product_ID"]].groupby("User_ID").agg({"Purchase":sum, "Product_ID": pd.Series.count})
# Out:
# C:\Users\Osas\AppData\Local\Temp\ipykernel_4072\3465241630.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df_ = df[['User_ID', 'Purchase', "Product_ID"]].groupby("User_ID").agg({"Purchase":sum, "Product_ID": pd.Series.count})

# %%
df_
# Out:
#          Purchase  Product_ID
# User_ID
# 1000001    333481          34
# 1000002    810353          76
# 1000003    341635          29
# 1000004    205987          13
# 1000005    821001         106
# ...           ...         ...
# 1006036   3821666         476
# 1006037   1075037         116
# 1006038     80859          10
# 1006039    554504          67
# 1006040   1562615         169
#
# [5891 rows x 2 columns]

# %%
df_.rename(columns=  {"Product_ID":"Total Purchase"})
# Out:
#          Purchase  Total Purchase
# User_ID
# 1000001    333481              34
# 1000002    810353              76
# 1000003    341635              29
# 1000004    205987              13
# 1000005    821001             106
# ...           ...             ...
# 1006036   3821666             476
# 1006037   1075037             116
# 1006038     80859              10
# 1006039    554504              67
# 1006040   1562615             169
#
# [5891 rows x 2 columns]

# %%
df["User_ID"].unique().size
# Out:
# 5891

# %%
df[["User_ID", "Gender", "Purchase"]].groupby(["User_ID", "Gender"]).agg({"Purchase":sum})
# Out:
# C:\Users\Osas\AppData\Local\Temp\ipykernel_4072\1742377966.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df[["User_ID", "Gender", "Purchase"]].groupby(["User_ID", "Gender"]).agg({"Purchase":sum})
#                 Purchase
# User_ID Gender
# 1000001 F         333481
# 1000002 M         810353
# 1000003 M         341635
# 1000004 M         205987
# 1000005 M         821001
# ...                  ...
# 1006036 F        3821666
# 1006037 F        1075037
# 1006038 F          80859
# 1006039 F         554504
# 1006040 M        1562615
#
# [5891 rows x 1 columns]

# %% [markdown]
# #### Visualization of total sum of purchase from both gender

# %%
# df.groupby(["Gender"]).sum()["Purchase"].plot(kind = "pie", y = "Purchase", autopct = "%.1f")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df[["Gender", "Purchase"]].groupby("Gender").agg({"Purchase":sum}) #Male gender had the highest purchase
# Out:
# C:\Users\Osas\AppData\Local\Temp\ipykernel_4072\2792764277.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df[["Gender", "Purchase"]].groupby("Gender").agg({"Purchase":sum}) #Male gender had the highest purchase
#           Purchase
# Gender
# F       1164624021
# M       3853044357

# %%
plt.figure(figsize = (6, 6))
barplot = sns.barplot(data = df, x = "Gender", y = "Purchase")

# %% [markdown]
# #### Analysis between age and marital status

# %%
df.groupby(["Age", "Marital_Status"]).sum()["Purchase"].plot(kind = "bar", hue = "Marital_Status")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.groupby(["Age", "Marital_Status"]).sum()["Purchase"].plot(kind = "bar", hue = "Marital_Status")
#
# File c:\Users\Osas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\Osas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
df.groupby(["Age", "Marital_Status"])

# %%
df.groupby("Marital_Status").size().plot(kind = "pie")

# %%
sns.countplot(data = df, x = "Age", hue = "Marital_Status")

# %%
df.head()

# %%
df.groupby(["Age", "Product_Category_1"]).size()

# %%
 df.head()

# %%
df.groupby("City_Category").sum()["Purchase"].plot(kind = "line")
